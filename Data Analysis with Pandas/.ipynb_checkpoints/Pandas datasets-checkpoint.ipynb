# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\kd\\Desktop\\Python mega course\\Data Analysis with Pandas\\supermarkets.csv")
df.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1 = pd.read_json("C:\\Users\\kd\\Desktop\\Python mega course\\Data Analysis with Pandas\\supermarkets.json")
df1.set_index('ID')
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df2 = pd.read_excel("C:\\Users\\kd\\Desktop\\Python mega course\\Data Analysis with Pandas\\supermarkets.xlsx", sheetname = 0)
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3 = pd.read_csv("C:\\Users\\kd\\Desktop\\Python mega course\\Data Analysis with Pandas\\supermarkets-commas.txt")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pd.read_csv("C:\\Users\\kd\\Desktop\\Python mega course\\Data Analysis with Pandas\\supermarkets-semi-colons.txt", sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_csv("http://www.pythonhow.com/supermarkets.csv")
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = df5.set_index("Address")

# %%
df5.loc["735 Dolores St":"332 Hill St", "Country":"ID"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [735 Dolores St, 332 Hill St]

# %%
df5.loc["332 Hill St", "Country"]
# Out:
# 'USA'

# %%
list(df5.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df5.iloc[1:3,1:4]
# Out:
#                          City             State Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA

# %%
df5=df5.drop("332 Hill St", 0)

# %%
df5.ix[3, 'Name']
df5.ix[4, 5]
# Out:
# C:\Users\kd\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 20L

# %%
df5["Contient"] = df5.shape[0]*["North America"]

# %%
df5
# Out:
#                 ID           City       State Country         Name Employees  \
# Address
# 3666 21st St     1  San Francisco    CA 94114     USA      Madeira         8
# 735 Dolores St   2  San Francisco    CA 94119     USA  Bready Shop        15
# 3995 23rd St     4  San Francisco    CA 94114     USA   Ben's Shop        10
# 1056 Sanchez St  5  San Francisco  California     USA      Sanchez        12
# 551 Alvarado St  6  San Francisco    CA 94114     USA   Richvalley        20
#
#                       Contient                Continent
# Address
# 3666 21st St     North America  USA,USANorth AmericaUSA
# 735 Dolores St   North America  USA,USANorth AmericaUSA
# 3995 23rd St     North America  USA,USANorth AmericaUSA
# 1056 Sanchez St  North America  USA,USANorth AmericaUSA
# 551 Alvarado St  North America  USA,USANorth AmericaUSA

# %%
df5["Continent"] = df5["Country"] + "," + df5["Continent"]

# %%
df5
# Out:
#                 ID           City       State Country         Name Employees  \
# Address
# 3666 21st St     1  San Francisco    CA 94114     USA      Madeira         8
# 735 Dolores St   2  San Francisco    CA 94119     USA  Bready Shop        15
# 3995 23rd St     4  San Francisco    CA 94114     USA   Ben's Shop        10
# 1056 Sanchez St  5  San Francisco  California     USA      Sanchez        12
# 551 Alvarado St  6  San Francisco    CA 94114     USA   Richvalley        20
#
#                       Contient                    Continent
# Address
# 3666 21st St     North America  USA,USA,USANorth AmericaUSA
# 735 Dolores St   North America  USA,USA,USANorth AmericaUSA
# 3995 23rd St     North America  USA,USA,USANorth AmericaUSA
# 1056 Sanchez St  North America  USA,USA,USANorth AmericaUSA
# 551 Alvarado St  North America  USA,USA,USANorth AmericaUSA

# %%
df_5=df5.T

# %%
df5_t
# Out:
# Address               3666 21st St           735 Dolores St  \
# ID                               1                        2
# City                 San Francisco            San Francisco
# State                     CA 94114                 CA 94119
# Country                        USA                      USA
# Name                       Madeira              Bready Shop
# Employees                        8                       15
# Contient             North America            North America
# Continent  USA,USANorth AmericaUSA  USA,USANorth AmericaUSA
#
# Address                332 Hill St             3995 23rd St  \
# ID                               3                        4
# City                 San Francisco            San Francisco
# State             California 94114                 CA 94114
# Country                        USA                      USA
# Name                   Super River               Ben's Shop
# Employees                       25                       10
# ...

# %%
len(df5_t.index)
# Out:
# 8

# %%
df5_t["My_Address"] = ["My City", "My Country", 10, 7, "My Shop", "My State", "My Continent"]

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim()

# %%
n = nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
n.longitude
# Out:
# -122.4317141

# %%
n.latitude
# Out:
# 37.7529648

# %%
import pandas
df7 = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7["Address"] = df["Address"] + "," + df["City"] + "," + df["State"] + "," + df["Country"]

# %%
df7
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df7["Coordinate"] = df7["Address"].apply(nom.geocode)

# %%
df7
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                           Corodinate  \
# 0  (21st Street, Mission District, SF, California...
# ...

# %%
df7.Coordinate[0].latitude
# Out:
# 37.7570511

# %%
df7.Coordinate[0].longitude
# Out:
# -122.4188036

# %%
df["Latitude"] = df["Coordinate"].apply(lambda: x.latitude if x != None else None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-a85cd06a3aff> in <module>()
# ----> 1 df["Latitude"] = df["Coordinate"].apply(lambda: x.latitude if x != None else None)
#
# C:\Users\kd\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\Users\kd\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\Users\kd\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
# ...
